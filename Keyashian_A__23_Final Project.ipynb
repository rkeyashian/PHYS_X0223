# %%
import random
import numpy as np 
from scipy.optimize import curve_fit
from collections import Counter

#First Trial conditions
print("##############################################")
print("First Trial Conditions")
print("##############################################")

class Particle_1:
    def __init__(self):
        self.x = 0
        self.y = 0
        self.energy = 1250

    def move(self):
        if self.energy <= 0: #stop moving if no energy left 
            return False

#initial move in positive-x direction
        if self.x == 0 and self.y == 0: 
            self.x += 4
            self.energy -= 4 
            return True

#Monte Carlo

        rand_num = random.random()
        if rand_num < 0.8: #80% chance
            if self.energy >=1: #check to make sure there is enough energy
                self.x +=1
                self.energy -=1
            else:
                return False #particle stops. no more energy

        elif rand_num < 0.9: #10% chance it moves in the negative y-direction
            energy_loss = self.get_energy_loss()
            if self.energy >= energy_loss: #check if there is enough energy
                self.y -= 1
                self.energy -= energy_loss
            else:
                return False #No more energy

        else:  # 10% chance to move in positive y
            energy_loss = self.get_energy_loss()
            if self.energy >= energy_loss: #check if there is enough energy
                self.y += 1
                self.energy -= energy_loss
            else:
                return False #No more energy
        return True #successful move


    def get_energy_loss(self):
        rand_num = random.random()
        if rand_num < 0.7:
            return 2
        elif rand_num < 0.95:
            return 5
        else:
            return 15

    def __repr__(self): #For printing out particle object nicely
        return f"Particle_1(x={self.x}, y={self.y}, energy={self.energy})"


def run_simulation(num_simulations):
    final_x_positions = []
    for _ in range(num_simulations):
        particle = Particle_1()
        while particle.move():
            pass  # Continue moving until energy is depleted
        final_x_positions.append(particle.x)
    return final_x_positions

#Run the simulation and print out the results
num_simulations = 1000
final_x_positions = run_simulation(num_simulations)
x_counts = Counter(final_x_positions)

#preparing x-data for curve fitting
x_values = np.array(list(x_counts.keys()))
probabilities = np.array(list(x_counts.values())) / num_simulations 

#define the fitting function 
def exponential_fit(x, A):
    return np.exp(-A * x)

try:
    alpha = curve_fit(exponential_fit, x_values, probabilities)
    A = alpha[0]
    print("Fitted parameter A:", A)

except RuntimeError as e:
    print("Error during curve fitting")

print("Distribution of final x-positions:")
x_counts = Counter(final_x_positions)
for x, count in x_counts.items():
    print(f"x = {x}: {count} particles")


#Second Trial Conditions
print("##############################################")
print("Second Trial Conditions")
print("##############################################")

def gaussian_energy():
    return int(np.random.normal(loc=650, scale=250))


class Particle_2:
    def __init__(self):
        self.x = 0
        self.y = 0
        self.energy = gaussian_energy()

    def move(self):
        if self.energy <= 0: #stop moving if no energy left 
            return False

#initial move in positive-x direction
        if self.x == 0 and self.y == 0: 
            self.x += 4
            self.energy -= 4 
            return True

#Monte Carlo

        rand_num = random.random()
        if rand_num < 0.8: #80% chance
            if self.energy >=1: #check to make sure there is enough energy
                self.x +=1
                self.energy -=1
            else:
                return False #particle stops. no more energy

        elif rand_num < 0.9: #10% chance it moves in the negative y-direction
            energy_loss = self.get_energy_loss()
            if self.energy >= energy_loss: #check if there is enough energy
                self.y -= 1
                self.energy -= energy_loss
            else:
                return False #No more energy

        else:  # 10% chance to move in positive y
            energy_loss = self.get_energy_loss()
            if self.energy >= energy_loss: #check if there is enough energy
                self.y += 1
                self.energy -= energy_loss
            else:
                return False #No more energy
        return True #successful move


    def get_energy_loss(self):
        rand_num = random.random()
        if rand_num < 0.7:
            return 2
        elif rand_num < 0.95:
            return 5
        else:
            return 15

    def __repr__(self): #For printing out particle object nicely
        return f"Particle_1(x={self.x}, y={self.y}, energy={self.energy})"


def run_simulation2(num_simulations2):
    final_x_positions = []
    for _ in range(num_simulations2):
        particle = Particle_2()
        while particle.move():
            pass  # Continue moving until energy is depleted
        final_x_positions.append(particle.x)
    return final_x_positions

#Run the simulation and print out the results
num_simulations2 = 1000
final_x_positions2 = run_simulation2(num_simulations2)
x_counts2 = Counter(final_x_positions2)

#preparing x-data for curve fitting
x_values2 = np.array(list(x_counts2.keys()))
probabilities2 = np.array(list(x_counts2.values())) / num_simulations2 

#define the fitting function 
def exponential_fit2(x, A):
    return np.exp(-A * x)

try:
    alpha2 = curve_fit(exponential_fit2, x_values2, probabilities2)
    A2 = alpha2[0]
    print("Fitted parameter A:", A2)

except RuntimeError as e:
    print("Error during curve fitting")

print("Distribution of final x-positions:")
x_counts2 = Counter(final_x_positions2)
for x, count in x_counts2.items():
    print(f"x = {x}: {count} particles")
# Out:
# ##############################################
# First Trial Conditions
# ##############################################
# C:\Users\rkeyashian\AppData\Local\Temp\ipykernel_29468\908839140.py:91: OptimizeWarning: Covariance of the parameters could not be estimated
#   alpha = curve_fit(exponential_fit, x_values, probabilities)
# Fitted parameter A: [1.]
# Distribution of final x-positions:
# x = 655: 17 particles
# x = 607: 1 particles
# x = 615: 5 particles
# x = 679: 13 particles
# x = 749: 2 particles
# x = 701: 10 particles
# x = 682: 19 particles
# x = 644: 5 particles
# x = 760: 3 particles
# x = 692: 12 particles
# x = 673: 9 particles
# x = 717: 11 particles
# x = 683: 11 particles
# x = 726: 6 particles
# x = 709: 6 particles
# x = 680: 13 particles
# x = 686: 13 particles
# x = 670: 16 particles
# x = 700: 15 particles
# x = 656: 10 particles
# x = 702: 10 particles
# x = 662: 16 particles
# x = 671: 5 particles
# x = 688: 12 particles
# x = 695: 9 particles
# x = 675: 14 particles
# x = 681: 14 particles
# x = 668: 10 particles
# x = 731: 1 particles
# x = 664: 13 particles
# x = 631: 3 particles
# x = 690: 11 particles
# x = 693: 7 particles
# x = 649: 9 particles
# x = 741: 4 particles
# x = 630: 5 particles
# x = 638: 8 particles
# x = 666: 8 particles
# x = 633: 6 particles
# x = 684: 10 particles
# x = 691: 12 particles
# x = 650: 12 particles
# x = 704: 11 particles
# x = 665: 12 particles
# x = 721: 5 particles
# x = 667: 8 particles
# x = 689: 10 particles
# x = 641: 9 particles
# x = 676: 14 particles
# x = 623: 4 particles
# x = 696: 13 particles
# x = 669: 17 particles
# x = 654: 17 particles
# x = 724: 4 particles
# x = 677: 14 particles
# x = 725: 4 particles
# x = 739: 6 particles
# x = 646: 8 particles
# x = 703: 5 particles
# x = 642: 7 particles
# x = 712: 8 particles
# x = 678: 6 particles
# x = 617: 4 particles
# x = 627: 9 particles
# x = 720: 5 particles
# x = 626: 4 particles
# x = 632: 3 particles
# x = 674: 9 particles
# x = 740: 1 particles
# x = 734: 4 particles
# x = 707: 5 particles
# x = 652: 12 particles
# x = 697: 11 particles
# x = 714: 5 particles
# x = 699: 9 particles
# x = 694: 11 particles
# x = 698: 12 particles
# x = 636: 7 particles
# x = 687: 15 particles
# x = 663: 10 particles
# x = 588: 1 particles
# x = 661: 14 particles
# x = 730: 2 particles
# x = 659: 5 particles
# x = 713: 7 particles
# x = 722: 3 particles
# x = 601: 2 particles
# x = 723: 11 particles
# x = 732: 1 particles
# x = 611: 2 particles
# x = 643: 5 particles
# x = 640: 4 particles
# x = 647: 3 particles
# x = 610: 2 particles
# x = 685: 13 particles
# x = 635: 4 particles
# x = 639: 5 particles
# x = 736: 3 particles
# x = 735: 6 particles
# x = 620: 3 particles
# x = 589: 1 particles
# x = 645: 3 particles
# x = 657: 7 particles
# x = 628: 5 particles
# x = 711: 3 particles
# x = 648: 6 particles
# x = 718: 6 particles
# x = 706: 12 particles
# x = 705: 9 particles
# x = 586: 2 particles
# x = 651: 8 particles
# x = 637: 6 particles
# x = 614: 1 particles
# x = 634: 4 particles
# x = 710: 8 particles
# x = 733: 3 particles
# x = 708: 7 particles
# x = 599: 1 particles
# x = 622: 2 particles
# x = 715: 6 particles
# x = 738: 4 particles
# x = 618: 2 particles
# x = 719: 2 particles
# x = 672: 7 particles
# x = 789: 1 particles
# x = 613: 2 particles
# x = 619: 5 particles
# x = 629: 2 particles
# x = 660: 12 particles
# x = 602: 1 particles
# x = 729: 2 particles
# x = 716: 2 particles
# x = 653: 1 particles
# x = 753: 2 particles
# x = 658: 8 particles
# x = 796: 1 particles
# x = 727: 3 particles
# x = 612: 2 particles
# x = 603: 1 particles
# x = 757: 2 particles
# x = 756: 2 particles
# x = 598: 1 particles
# x = 744: 2 particles
# x = 747: 3 particles
# x = 621: 1 particles
# x = 600: 2 particles
# x = 625: 1 particles
# x = 772: 1 particles
# x = 751: 1 particles
# x = 766: 1 particles
# x = 606: 1 particles
# x = 745: 2 particles
# x = 624: 2 particles
# x = 577: 1 particles
# x = 616: 2 particles
# x = 742: 1 particles
# x = 750: 1 particles
# x = 755: 2 particles
# x = 748: 1 particles
# ##############################################
# Second Trial Conditions
# ##############################################
# Fitted parameter A: [0.87551668]
# Distribution of final x-positions:
# x = 346: 1 particles
# x = 348: 8 particles
# x = 353: 3 particles
# x = 349: 3 particles
# x = 253: 3 particles
# x = 502: 2 particles
# x = 115: 2 particles
# x = 548: 1 particles
# x = 398: 4 particles
# x = 121: 3 particles
# x = 344: 10 particles
# x = 295: 5 particles
# x = 91: 1 particles
# x = 351: 3 particles
# x = 515: 2 particles
# x = 287: 3 particles
# x = 708: 1 particles
# x = 235: 2 particles
# x = 334: 7 particles
# x = 597: 2 particles
# x = 388: 4 particles
# x = 279: 4 particles
# x = 490: 1 particles
# x = 330: 3 particles
# x = 381: 6 particles
# x = 632: 1 particles
# x = 363: 2 particles
# x = 585: 1 particles
# x = 680: 1 particles
# x = 177: 1 particles
# x = 393: 5 particles
# x = 266: 3 particles
# x = 418: 2 particles
# x = 379: 4 particles
# x = 350: 3 particles
# x = 312: 2 particles
# x = 413: 3 particles
# x = 362: 4 particles
# x = 233: 3 particles
# x = 308: 4 particles
# x = 357: 5 particles
# x = 151: 3 particles
# x = 258: 3 particles
# x = 139: 2 particles
# x = 264: 2 particles
# x = 231: 2 particles
# x = 343: 6 particles
# x = 342: 3 particles
# x = 234: 4 particles
# x = 232: 3 particles
# x = 299: 3 particles
# x = 549: 2 particles
# x = 335: 2 particles
# x = 314: 4 particles
# x = 483: 2 particles
# x = 294: 2 particles
# x = 489: 1 particles
# x = 157: 2 particles
# x = 527: 1 particles
# x = 532: 2 particles
# x = 394: 3 particles
# x = 178: 2 particles
# x = 305: 5 particles
# x = 368: 6 particles
# x = 444: 4 particles
# x = 197: 1 particles
# x = 218: 3 particles
# x = 316: 4 particles
# x = 430: 6 particles
# x = 425: 3 particles
# x = 563: 2 particles
# x = 339: 4 particles
# x = 275: 4 particles
# x = 501: 3 particles
# x = 61: 1 particles
# x = 86: 1 particles
# x = 508: 1 particles
# x = 241: 2 particles
# x = 329: 3 particles
# x = 364: 3 particles
# x = 359: 5 particles
# x = 649: 1 particles
# x = 332: 5 particles
# x = 438: 3 particles
# x = 369: 5 particles
# x = 283: 4 particles
# x = 578: 3 particles
# x = 313: 4 particles
# x = 180: 1 particles
# x = 386: 3 particles
# x = 107: 1 particles
# x = 358: 3 particles
# x = 224: 3 particles
# x = 397: 3 particles
# x = 257: 5 particles
# x = 396: 1 particles
# x = 614: 1 particles
# x = 484: 2 particles
# x = 347: 1 particles
# x = 182: 1 particles
# x = 498: 4 particles
# x = 495: 1 particles
# x = 274: 2 particles
# x = 456: 3 particles
# x = 451: 6 particles
# x = 130: 2 particles
# x = 136: 3 particles
# x = 147: 1 particles
# x = 409: 2 particles
# x = 612: 1 particles
# x = 439: 2 particles
# x = 552: 3 particles
# x = 0: 4 particles
# x = 69: 2 particles
# x = 289: 1 particles
# x = 411: 3 particles
# x = 173: 2 particles
# x = 443: 2 particles
# x = 252: 2 particles
# x = 174: 4 particles
# x = 209: 3 particles
# x = 595: 1 particles
# x = 186: 1 particles
# x = 251: 4 particles
# x = 537: 2 particles
# x = 575: 2 particles
# x = 506: 1 particles
# x = 272: 1 particles
# x = 436: 3 particles
# x = 273: 1 particles
# x = 340: 5 particles
# x = 278: 3 particles
# x = 146: 1 particles
# x = 592: 1 particles
# x = 486: 2 particles
# x = 454: 2 particles
# x = 427: 1 particles
# x = 356: 4 particles
# x = 449: 4 particles
# x = 345: 3 particles
# x = 202: 1 particles
# x = 82: 1 particles
# x = 452: 2 particles
# x = 304: 1 particles
# x = 435: 2 particles
# x = 284: 4 particles
# x = 382: 3 particles
# x = 239: 3 particles
# x = 265: 3 particles
# x = 194: 2 particles
# x = 424: 4 particles
# x = 600: 1 particles
# x = 499: 1 particles
# x = 390: 6 particles
# x = 567: 1 particles
# x = 426: 3 particles
# x = 360: 3 particles
# x = 523: 2 particles
# x = 201: 3 particles
# x = 138: 1 particles
# x = 547: 1 particles
# x = 259: 6 particles
# x = 441: 4 particles
# x = 380: 3 particles
# x = 262: 5 particles
# x = 522: 4 particles
# x = 615: 1 particles
# x = 551: 4 particles
# x = 324: 3 particles
# x = 216: 1 particles
# x = 134: 1 particles
# x = 280: 4 particles
# x = 341: 3 particles
# x = 36: 1 particles
# x = 640: 1 particles
# x = 539: 2 particles
# x = 399: 4 particles
# x = 311: 3 particles
# x = 664: 2 particles
# x = 445: 1 particles
# x = 428: 4 particles
# x = 355: 1 particles
# x = 32: 1 particles
# x = 385: 2 particles
# x = 337: 2 particles
# x = 323: 6 particles
# x = 301: 6 particles
# x = 505: 2 particles
# x = 292: 4 particles
# x = 371: 3 particles
# x = 584: 1 particles
# x = 204: 2 particles
# x = 684: 1 particles
# x = 512: 2 particles
# x = 705: 1 particles
# x = 263: 3 particles
# x = 374: 4 particles
# x = 604: 1 particles
# x = 709: 1 particles
# x = 213: 2 particles
# x = 433: 2 particles
# x = 297: 6 particles
# x = 623: 1 particles
# x = 421: 4 particles
# x = 467: 1 particles
# x = 285: 1 particles
# x = 331: 4 particles
# x = 410: 3 particles
# x = 404: 1 particles
# x = 510: 2 particles
# x = 432: 1 particles
# x = 126: 3 particles
# x = 589: 1 particles
# x = 535: 3 particles
# x = 472: 3 particles
# x = 244: 5 particles
# x = 321: 6 particles
# x = 246: 3 particles
# x = 81: 2 particles
# x = 526: 2 particles
# x = 406: 3 particles
# x = 106: 1 particles
# x = 465: 3 particles
# x = 652: 1 particles
# x = 260: 3 particles
# x = 493: 1 particles
# x = 479: 2 particles
# x = 326: 2 particles
# x = 555: 3 particles
# x = 307: 3 particles
# x = 403: 2 particles
# x = 196: 1 particles
# x = 271: 4 particles
# x = 327: 2 particles
# x = 588: 1 particles
# x = 700: 1 particles
# x = 434: 1 particles
# x = 590: 1 particles
# x = 93: 1 particles
# x = 286: 2 particles
# x = 63: 1 particles
# x = 554: 1 particles
# x = 519: 3 particles
# x = 377: 3 particles
# x = 156: 1 particles
# x = 325: 5 particles
# x = 318: 4 particles
# x = 395: 1 particles
# x = 185: 1 particles
# x = 581: 2 particles
# x = 103: 1 particles
# x = 470: 3 particles
# x = 206: 1 particles
# x = 361: 2 particles
# x = 688: 1 particles
# x = 542: 1 particles
# x = 131: 1 particles
# x = 73: 1 particles
# x = 478: 4 particles
# x = 509: 2 particles
# x = 181: 1 particles
# x = 162: 1 particles
# x = 758: 1 particles
# x = 641: 1 particles
# x = 367: 3 particles
# x = 474: 4 particles
# x = 220: 3 particles
# x = 322: 4 particles
# x = 487: 1 particles
# x = 546: 3 particles
# x = 310: 5 particles
# x = 300: 1 particles
# x = 513: 2 particles
# x = 564: 1 particles
# x = 167: 2 particles
# x = 566: 3 particles
# x = 248: 2 particles
# x = 476: 2 particles
# x = 315: 2 particles
# x = 626: 1 particles
# x = 254: 1 particles
# x = 199: 2 particles
# x = 603: 2 particles
# x = 225: 1 particles
# x = 387: 3 particles
# x = 407: 1 particles
# x = 416: 2 particles
# x = 153: 1 particles
# x = 518: 3 particles
# x = 37: 1 particles
# x = 113: 2 particles
# x = 643: 1 particles
# x = 291: 2 particles
# x = 415: 2 particles
# x = 570: 2 particles
# x = 365: 2 particles
# x = 267: 2 particles
# x = 129: 1 particles
# x = 320: 1 particles
# x = 460: 2 particles
# x = 624: 1 particles
# x = 372: 4 particles
# x = 423: 2 particles
# x = 188: 2 particles
# x = 630: 1 particles
# x = 376: 3 particles
# x = 503: 3 particles
# x = 417: 3 particles
# x = 229: 3 particles
# x = 302: 2 particles
# x = 155: 1 particles
# x = 511: 2 particles
# x = 317: 3 particles
# x = 789: 1 particles
# x = 269: 2 particles
# x = 408: 1 particles
# x = 149: 1 particles
# x = 384: 2 particles
# x = 469: 1 particles
# x = 586: 1 particles
# x = 211: 2 particles
# x = 477: 3 particles
# x = 352: 5 particles
# x = 354: 2 particles
# x = 685: 1 particles
# x = 389: 1 particles
# x = 261: 1 particles
# x = 494: 1 particles
# x = 222: 1 particles
# x = 236: 1 particles
# x = 45: 1 particles
# x = 84: 1 particles
# x = 293: 2 particles
# x = 556: 1 particles
# x = 221: 2 particles
# x = 607: 1 particles
# x = 122: 1 particles
# x = 198: 1 particles
# x = 703: 1 particles
# x = 296: 1 particles
# x = 569: 1 particles
# x = 223: 2 particles
# x = 504: 1 particles
# x = 481: 4 particles
# x = 298: 1 particles
# x = 528: 1 particles
# x = 545: 1 particles
# x = 270: 3 particles
# x = 414: 2 particles
# x = 328: 3 particles
# x = 98: 1 particles
# x = 191: 1 particles
# x = 90: 1 particles
# x = 276: 5 particles
# x = 288: 2 particles
# x = 120: 1 particles
# x = 608: 1 particles
# x = 102: 1 particles
# x = 466: 5 particles
# x = 373: 2 particles
# x = 533: 2 particles
# x = 602: 1 particles
# x = 419: 2 particles
# x = 250: 1 particles
# x = 455: 1 particles
# x = 558: 1 particles
# x = 446: 3 particles
# x = 458: 2 particles
# x = 422: 1 particles
# x = 620: 1 particles
# x = 49: 1 particles
# x = 391: 2 particles
# x = 534: 2 particles
# x = 400: 4 particles
# x = 277: 1 particles
# x = 429: 3 particles
# x = 190: 1 particles
# x = 497: 1 particles
# x = 247: 2 particles
# x = 520: 2 particles
# x = 468: 3 particles
# x = 132: 1 particles
# x = 207: 3 particles
# x = 210: 2 particles
# x = 168: 1 particles
# x = 742: 1 particles
# x = 319: 4 particles
# x = 226: 2 particles
# x = 601: 1 particles
# x = 227: 3 particles
# x = 192: 2 particles
# x = 282: 2 particles
# x = 496: 1 particles
# x = 462: 2 particles
# x = 366: 2 particles
# x = 464: 2 particles
# x = 485: 3 particles
# x = 463: 2 particles
# x = 243: 2 particles
# x = 290: 1 particles
# x = 249: 1 particles
# x = 128: 1 particles
# x = 303: 1 particles
# x = 41: 1 particles
# x = 184: 1 particles
# x = 392: 2 particles
# x = 165: 1 particles
# x = 203: 1 particles
# x = 46: 1 particles
# x = 540: 1 particles
# x = 237: 2 particles
# x = 553: 2 particles
# x = 482: 1 particles
# x = 541: 1 particles
# x = 338: 2 particles
# x = 613: 1 particles
# x = 142: 2 particles
# x = 163: 2 particles
# x = 183: 1 particles
# x = 565: 1 particles
# x = 42: 1 particles
# x = 255: 1 particles
# x = 442: 1 particles
# x = 538: 1 particles
# x = 530: 1 particles
# x = 212: 1 particles
# x = 646: 1 particles
# x = 219: 1 particles
# x = 405: 1 particles
# x = 150: 1 particles
# x = 529: 1 particles
# x = 480: 2 particles
# x = 74: 1 particles
# x = 112: 1 particles
# x = 21: 1 particles
# x = 87: 1 particles
# x = 568: 1 particles
# x = 187: 1 particles
# x = 104: 1 particles
# x = 370: 1 particles
# x = 164: 1 particles
# x = 587: 1 particles
# x = 402: 1 particles
# x = 117: 1 particles
# x = 230: 1 particles
# x = 491: 1 particles
# x = 333: 1 particles
# x = 215: 1 particles
# x = 245: 1 particles
# x = 100: 1 particles
# x = 205: 1 particles
# x = 175: 1 particles
# x = 375: 1 particles
# x = 638: 1 particles
# x = 200: 1 particles
# x = 593: 1 particles
# x = 78: 1 particles
# x = 459: 1 particles
# x = 217: 1 particles
# x = 629: 1 particles
# x = 617: 1 particles
# x = 240: 1 particles
# x = 725: 1 particles
# x = 517: 1 particles
# x = 594: 1 particles
# C:\Users\rkeyashian\AppData\Local\Temp\ipykernel_29468\908839140.py:190: RuntimeWarning: overflow encountered in exp
#   return np.exp(-A * x)
